# %%
#HW_2
#source https://lucytalksdata.com/the-modern-tokenization-stack-for-nlp-byte-pair-encoding/
#https://lucytalksdata.com/the-modern-tokenization-stack-for-nlp-byte-pair-encoding/https://towardsdatascience.com/byte-pair-encoding-the-dark-horse-of-modern-nlp-eb36c7df4f10


from numpy.lib.function_base import kaiser
import re
from collections import Counter, defaultdict


def process_vocab(corpus: str) -> dict:
    char = [" ".join(word) + " </w>" for word in corpus.split()]
    vocabulary = Counter(char)  
    return vocabulary


def get_pairs(vocabulary: dict) -> dict:
    pairs = defaultdict(int)
    for word, frequency in vocabulary.items():
        symbols = word.split()
        for i in range(len(symbols) - 1):
            pairs[symbols[i], symbols[i + 1]] += frequency
    return pairs


def merge_vocabulary(pair: tuple, initial_vocabulary: dict) -> dict:
    vocabulary_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in initial_vocabulary:
        word_out = p.sub(''.join(pair), word)
        vocabulary_out[word_out] = initial_vocabulary[word]
    return vocabulary_out

#corpus="low low low low low lowest lowest newer newer newer newer newer newer wider wider wider new new"
corpus="Baker Betty Lou bought some butter. But, it made her batter bitter. So, Baker Betty Lou bought some better butter to make her bitter batter better."
vocabulary = process_vocab(corpus)  # Step 1

k = 9
for i in range(k):
    print("iteration",i)
    print("--------------")
    pairs = get_pairs(vocabulary)  # Step 2
    print("initial vocab",dict(pairs))
    if not pairs:
        break
    best_pair = max(pairs, key=pairs.get)
    print("merge",best_pair)
    vocabulary = merge_vocabulary(best_pair, vocabulary)
    print("after merging corpus is:",vocabulary)
    print("\n\n")
# Out:
# iteration 0
# --------------
# initial vocab {('B', 'a'): 2, ('a', 'k'): 3, ('k', 'e'): 3, ('e', 'r'): 12, ('r', '</w>'): 9, ('B', 'e'): 2, ('e', 't'): 4, ('t', 't'): 10, ('t', 'y'): 2, ('y', '</w>'): 2, ('L', 'o'): 2, ('o', 'u'): 4, ('u', '</w>'): 2, ('b', 'o'): 2, ('u', 'g'): 2, ('g', 'h'): 2, ('h', 't'): 2, ('t', '</w>'): 3, ('s', 'o'): 2, ('o', 'm'): 2, ('m', 'e'): 2, ('e', '</w>'): 4, ('b', 'u'): 2, ('u', 't'): 3, ('t', 'e'): 8, ('r', '.'): 3, ('.', '</w>'): 3, ('B', 'u'): 1, ('t', ','): 1, (',', '</w>'): 2, ('i', 't'): 3, ('m', 'a'): 2, ('a', 'd'): 1, ('d', 'e'): 1, ('h', 'e'): 2, ('b', 'a'): 2, ('a', 't'): 2, ('b', 'i'): 2, ('S', 'o'): 1, ('o', ','): 1, ('b', 'e'): 2, ('t', 'o'): 1, ('o', '</w>'): 1}
# merge ('e', 'r')
# after merging corpus is: {'B a k er </w>': 2, 'B e t t y </w>': 2, 'L o u </w>': 2, 'b o u g h t </w>': 2, 's o m e </w>': 2, 'b u t t er . </w>': 1, 'B u t , </w>': 1, 'i t </w>': 1, 'm a d e </w>': 1, 'h er </w>': 2, 'b a t t er </w>': 2, 'b i t t er . </w>': 1, 'S o , </w>': 1, 'b e t t er </w>': 1, 'b u t t er </w>': 1, 't o </w>': 1, 'm a k e </w>': 1, 'b i t t er </w>': 1, 'b e t t er . </w>': 1}
#
#
#
# iteration 1
# --------------
# initial vocab {('B', 'a'): 2, ('a', 'k'): 3, ('k', 'er'): 2, ('er', '</w>'): 9, ('B', 'e'): 2, ('e', 't'): 4, ('t', 't'): 10, ('t', 'y'): 2, ('y', '</w>'): 2, ('L', 'o'): 2, ('o', 'u'): 4, ('u', '</w>'): 2, ('b', 'o'): 2, ('u', 'g'): 2, ('g', 'h'): 2, ('h', 't'): 2, ('t', '</w>'): 3, ('s', 'o'): 2, ('o', 'm'): 2, ('m', 'e'): 2, ('e', '</w>'): 4, ('b', 'u'): 2, ('u', 't'): 3, ('t', 'er'): 8, ('er', '.'): 3, ('.', '</w>'): 3, ('B', 'u'): 1, ('t', ','): 1, (',', '</w>'): 2, ('i', 't'): 3, ('m', 'a'): 2, ('a', 'd'): 1, ('d', 'e'): 1, ('h', 'er'): 2, ('b', 'a'): 2, ('a', 't'): 2, ('b', 'i'): 2, ('S', 'o'): 1, ('o', ','): 1, ('b', 'e'): 2, ('t', 'o'): 1, ('o', '</w>'): 1, ('k', 'e'): 1}
# merge ('t', 't')
# after merging corpus is: {'B a k er </w>': 2, 'B e tt y </w>': 2, 'L o u </w>': 2, 'b o u g h t </w>': 2, 's o m e </w>': 2, 'b u tt er . </w>': 1, 'B u t , </w>': 1, 'i t </w>': 1, 'm a d e </w>': 1, 'h er </w>': 2, 'b a tt er </w>': 2, 'b i tt er . </w>': 1, 'S o , </w>': 1, 'b e tt er </w>': 1, 'b u tt er </w>': 1, 't o </w>': 1, 'm a k e </w>': 1, 'b i tt er </w>': 1, 'b e tt er . </w>': 1}
#
#
#
# iteration 2
# --------------
# initial vocab {('B', 'a'): 2, ('a', 'k'): 3, ('k', 'er'): 2, ('er', '</w>'): 9, ('B', 'e'): 2, ('e', 'tt'): 4, ('tt', 'y'): 2, ('y', '</w>'): 2, ('L', 'o'): 2, ('o', 'u'): 4, ('u', '</w>'): 2, ('b', 'o'): 2, ('u', 'g'): 2, ('g', 'h'): 2, ('h', 't'): 2, ('t', '</w>'): 3, ('s', 'o'): 2, ('o', 'm'): 2, ('m', 'e'): 2, ('e', '</w>'): 4, ('b', 'u'): 2, ('u', 'tt'): 2, ('tt', 'er'): 8, ('er', '.'): 3, ('.', '</w>'): 3, ('B', 'u'): 1, ('u', 't'): 1, ('t', ','): 1, (',', '</w>'): 2, ('i', 't'): 1, ('m', 'a'): 2, ('a', 'd'): 1, ('d', 'e'): 1, ('h', 'er'): 2, ('b', 'a'): 2, ('a', 'tt'): 2, ('b', 'i'): 2, ('i', 'tt'): 2, ('S', 'o'): 1, ('o', ','): 1, ('b', 'e'): 2, ('t', 'o'): 1, ('o', '</w>'): 1, ('k', 'e'): 1}
# merge ('er', '</w>')
# after merging corpus is: {'B a k er</w>': 2, 'B e tt y </w>': 2, 'L o u </w>': 2, 'b o u g h t </w>': 2, 's o m e </w>': 2, 'b u tt er . </w>': 1, 'B u t , </w>': 1, 'i t </w>': 1, 'm a d e </w>': 1, 'h er</w>': 2, 'b a tt er</w>': 2, 'b i tt er . </w>': 1, 'S o , </w>': 1, 'b e tt er</w>': 1, 'b u tt er</w>': 1, 't o </w>': 1, 'm a k e </w>': 1, 'b i tt er</w>': 1, 'b e tt er . </w>': 1}
#
#
#
# iteration 3
# --------------
# initial vocab {('B', 'a'): 2, ('a', 'k'): 3, ('k', 'er</w>'): 2, ('B', 'e'): 2, ('e', 'tt'): 4, ('tt', 'y'): 2, ('y', '</w>'): 2, ('L', 'o'): 2, ('o', 'u'): 4, ('u', '</w>'): 2, ('b', 'o'): 2, ('u', 'g'): 2, ('g', 'h'): 2, ('h', 't'): 2, ('t', '</w>'): 3, ('s', 'o'): 2, ('o', 'm'): 2, ('m', 'e'): 2, ('e', '</w>'): 4, ('b', 'u'): 2, ('u', 'tt'): 2, ('tt', 'er'): 3, ('er', '.'): 3, ('.', '</w>'): 3, ('B', 'u'): 1, ('u', 't'): 1, ('t', ','): 1, (',', '</w>'): 2, ('i', 't'): 1, ('m', 'a'): 2, ('a', 'd'): 1, ('d', 'e'): 1, ('h', 'er</w>'): 2, ('b', 'a'): 2, ('a', 'tt'): 2, ('tt', 'er</w>'): 5, ('b', 'i'): 2, ('i', 'tt'): 2, ('S', 'o'): 1, ('o', ','): 1, ('b', 'e'): 2, ('t', 'o'): 1, ('o', '</w>'): 1, ('k', 'e'): 1}
# merge ('tt', 'er</w>')
# after merging corpus is: {'B a k er</w>': 2, 'B e tt y </w>': 2, 'L o u </w>': 2, 'b o u g h t </w>': 2, 's o m e </w>': 2, 'b u tt er . </w>': 1, 'B u t , </w>': 1, 'i t </w>': 1, 'm a d e </w>': 1, 'h er</w>': 2, 'b a tter</w>': 2, 'b i tt er . </w>': 1, 'S o , </w>': 1, 'b e tter</w>': 1, 'b u tter</w>': 1, 't o </w>': 1, 'm a k e </w>': 1, 'b i tter</w>': 1, 'b e tt er . </w>': 1}
#
#
#
# iteration 4
# --------------
# initial vocab {('B', 'a'): 2, ('a', 'k'): 3, ('k', 'er</w>'): 2, ('B', 'e'): 2, ('e', 'tt'): 3, ('tt', 'y'): 2, ('y', '</w>'): 2, ('L', 'o'): 2, ('o', 'u'): 4, ('u', '</w>'): 2, ('b', 'o'): 2, ('u', 'g'): 2, ('g', 'h'): 2, ('h', 't'): 2, ('t', '</w>'): 3, ('s', 'o'): 2, ('o', 'm'): 2, ('m', 'e'): 2, ('e', '</w>'): 4, ('b', 'u'): 2, ('u', 'tt'): 1, ('tt', 'er'): 3, ('er', '.'): 3, ('.', '</w>'): 3, ('B', 'u'): 1, ('u', 't'): 1, ('t', ','): 1, (',', '</w>'): 2, ('i', 't'): 1, ('m', 'a'): 2, ('a', 'd'): 1, ('d', 'e'): 1, ('h', 'er</w>'): 2, ('b', 'a'): 2, ('a', 'tter</w>'): 2, ('b', 'i'): 2, ('i', 'tt'): 1, ('S', 'o'): 1, ('o', ','): 1, ('b', 'e'): 2, ('e', 'tter</w>'): 1, ('u', 'tter</w>'): 1, ('t', 'o'): 1, ('o', '</w>'): 1, ('k', 'e'): 1, ('i', 'tter</w>'): 1}
# merge ('o', 'u')
# after merging corpus is: {'B a k er</w>': 2, 'B e tt y </w>': 2, 'L ou </w>': 2, 'b ou g h t </w>': 2, 's o m e </w>': 2, 'b u tt er . </w>': 1, 'B u t , </w>': 1, 'i t </w>': 1, 'm a d e </w>': 1, 'h er</w>': 2, 'b a tter</w>': 2, 'b i tt er . </w>': 1, 'S o , </w>': 1, 'b e tter</w>': 1, 'b u tter</w>': 1, 't o </w>': 1, 'm a k e </w>': 1, 'b i tter</w>': 1, 'b e tt er . </w>': 1}
#
#
#
# iteration 5
# --------------
# initial vocab {('B', 'a'): 2, ('a', 'k'): 3, ('k', 'er</w>'): 2, ('B', 'e'): 2, ('e', 'tt'): 3, ('tt', 'y'): 2, ('y', '</w>'): 2, ('L', 'ou'): 2, ('ou', '</w>'): 2, ('b', 'ou'): 2, ('ou', 'g'): 2, ('g', 'h'): 2, ('h', 't'): 2, ('t', '</w>'): 3, ('s', 'o'): 2, ('o', 'm'): 2, ('m', 'e'): 2, ('e', '</w>'): 4, ('b', 'u'): 2, ('u', 'tt'): 1, ('tt', 'er'): 3, ('er', '.'): 3, ('.', '</w>'): 3, ('B', 'u'): 1, ('u', 't'): 1, ('t', ','): 1, (',', '</w>'): 2, ('i', 't'): 1, ('m', 'a'): 2, ('a', 'd'): 1, ('d', 'e'): 1, ('h', 'er</w>'): 2, ('b', 'a'): 2, ('a', 'tter</w>'): 2, ('b', 'i'): 2, ('i', 'tt'): 1, ('S', 'o'): 1, ('o', ','): 1, ('b', 'e'): 2, ('e', 'tter</w>'): 1, ('u', 'tter</w>'): 1, ('t', 'o'): 1, ('o', '</w>'): 1, ('k', 'e'): 1, ('i', 'tter</w>'): 1}
# merge ('e', '</w>')
# after merging corpus is: {'B a k er</w>': 2, 'B e tt y </w>': 2, 'L ou </w>': 2, 'b ou g h t </w>': 2, 's o m e</w>': 2, 'b u tt er . </w>': 1, 'B u t , </w>': 1, 'i t </w>': 1, 'm a d e</w>': 1, 'h er</w>': 2, 'b a tter</w>': 2, 'b i tt er . </w>': 1, 'S o , </w>': 1, 'b e tter</w>': 1, 'b u tter</w>': 1, 't o </w>': 1, 'm a k e</w>': 1, 'b i tter</w>': 1, 'b e tt er . </w>': 1}
#
#
#
# iteration 6
# --------------
# initial vocab {('B', 'a'): 2, ('a', 'k'): 3, ('k', 'er</w>'): 2, ('B', 'e'): 2, ('e', 'tt'): 3, ('tt', 'y'): 2, ('y', '</w>'): 2, ('L', 'ou'): 2, ('ou', '</w>'): 2, ('b', 'ou'): 2, ('ou', 'g'): 2, ('g', 'h'): 2, ('h', 't'): 2, ('t', '</w>'): 3, ('s', 'o'): 2, ('o', 'm'): 2, ('m', 'e</w>'): 2, ('b', 'u'): 2, ('u', 'tt'): 1, ('tt', 'er'): 3, ('er', '.'): 3, ('.', '</w>'): 3, ('B', 'u'): 1, ('u', 't'): 1, ('t', ','): 1, (',', '</w>'): 2, ('i', 't'): 1, ('m', 'a'): 2, ('a', 'd'): 1, ('d', 'e</w>'): 1, ('h', 'er</w>'): 2, ('b', 'a'): 2, ('a', 'tter</w>'): 2, ('b', 'i'): 2, ('i', 'tt'): 1, ('S', 'o'): 1, ('o', ','): 1, ('b', 'e'): 2, ('e', 'tter</w>'): 1, ('u', 'tter</w>'): 1, ('t', 'o'): 1, ('o', '</w>'): 1, ('k', 'e</w>'): 1, ('i', 'tter</w>'): 1}
# merge ('a', 'k')
# after merging corpus is: {'B ak er</w>': 2, 'B e tt y </w>': 2, 'L ou </w>': 2, 'b ou g h t </w>': 2, 's o m e</w>': 2, 'b u tt er . </w>': 1, 'B u t , </w>': 1, 'i t </w>': 1, 'm a d e</w>': 1, 'h er</w>': 2, 'b a tter</w>': 2, 'b i tt er . </w>': 1, 'S o , </w>': 1, 'b e tter</w>': 1, 'b u tter</w>': 1, 't o </w>': 1, 'm ak e</w>': 1, 'b i tter</w>': 1, 'b e tt er . </w>': 1}
#
#
#
# iteration 7
# --------------
# initial vocab {('B', 'ak'): 2, ('ak', 'er</w>'): 2, ('B', 'e'): 2, ('e', 'tt'): 3, ('tt', 'y'): 2, ('y', '</w>'): 2, ('L', 'ou'): 2, ('ou', '</w>'): 2, ('b', 'ou'): 2, ('ou', 'g'): 2, ('g', 'h'): 2, ('h', 't'): 2, ('t', '</w>'): 3, ('s', 'o'): 2, ('o', 'm'): 2, ('m', 'e</w>'): 2, ('b', 'u'): 2, ('u', 'tt'): 1, ('tt', 'er'): 3, ('er', '.'): 3, ('.', '</w>'): 3, ('B', 'u'): 1, ('u', 't'): 1, ('t', ','): 1, (',', '</w>'): 2, ('i', 't'): 1, ('m', 'a'): 1, ('a', 'd'): 1, ('d', 'e</w>'): 1, ('h', 'er</w>'): 2, ('b', 'a'): 2, ('a', 'tter</w>'): 2, ('b', 'i'): 2, ('i', 'tt'): 1, ('S', 'o'): 1, ('o', ','): 1, ('b', 'e'): 2, ('e', 'tter</w>'): 1, ('u', 'tter</w>'): 1, ('t', 'o'): 1, ('o', '</w>'): 1, ('m', 'ak'): 1, ('ak', 'e</w>'): 1, ('i', 'tter</w>'): 1}
# merge ('e', 'tt')
# after merging corpus is: {'B ak er</w>': 2, 'B ett y </w>': 2, 'L ou </w>': 2, 'b ou g h t </w>': 2, 's o m e</w>': 2, 'b u tt er . </w>': 1, 'B u t , </w>': 1, 'i t </w>': 1, 'm a d e</w>': 1, 'h er</w>': 2, 'b a tter</w>': 2, 'b i tt er . </w>': 1, 'S o , </w>': 1, 'b e tter</w>': 1, 'b u tter</w>': 1, 't o </w>': 1, 'm ak e</w>': 1, 'b i tter</w>': 1, 'b ett er . </w>': 1}
#
#
#
# iteration 8
# --------------
# initial vocab {('B', 'ak'): 2, ('ak', 'er</w>'): 2, ('B', 'ett'): 2, ('ett', 'y'): 2, ('y', '</w>'): 2, ('L', 'ou'): 2, ('ou', '</w>'): 2, ('b', 'ou'): 2, ('ou', 'g'): 2, ('g', 'h'): 2, ('h', 't'): 2, ('t', '</w>'): 3, ('s', 'o'): 2, ('o', 'm'): 2, ('m', 'e</w>'): 2, ('b', 'u'): 2, ('u', 'tt'): 1, ('tt', 'er'): 2, ('er', '.'): 3, ('.', '</w>'): 3, ('B', 'u'): 1, ('u', 't'): 1, ('t', ','): 1, (',', '</w>'): 2, ('i', 't'): 1, ('m', 'a'): 1, ('a', 'd'): 1, ('d', 'e</w>'): 1, ('h', 'er</w>'): 2, ('b', 'a'): 2, ('a', 'tter</w>'): 2, ('b', 'i'): 2, ('i', 'tt'): 1, ('S', 'o'): 1, ('o', ','): 1, ('b', 'e'): 1, ('e', 'tter</w>'): 1, ('u', 'tter</w>'): 1, ('t', 'o'): 1, ('o', '</w>'): 1, ('m', 'ak'): 1, ('ak', 'e</w>'): 1, ('i', 'tter</w>'): 1, ('b', 'ett'): 1, ('ett', 'er'): 1}
# merge ('t', '</w>')
# after merging corpus is: {'B ak er</w>': 2, 'B ett y </w>': 2, 'L ou </w>': 2, 'b ou g h t</w>': 2, 's o m e</w>': 2, 'b u tt er . </w>': 1, 'B u t , </w>': 1, 'i t</w>': 1, 'm a d e</w>': 1, 'h er</w>': 2, 'b a tter</w>': 2, 'b i tt er . </w>': 1, 'S o , </w>': 1, 'b e tter</w>': 1, 'b u tter</w>': 1, 't o </w>': 1, 'm ak e</w>': 1, 'b i tter</w>': 1, 'b ett er . </w>': 1}
